# %%
import cv2
import numpy as np
import vizdoom as vzd
import gymnasium as gym
import matplotlib.pyplot as plt

from stable_baselines3 import A2C

# %%
import src

env = gym.make('ViZDoomBasic-v0', render_mode='rgb_array')

model = A2C('MultiInputPolicy', env, verbose=1)
model.learn(total_timesteps=1_000, progress_bar=True)

model.save('a2c_doom_agent')

# mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

obs = env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
# Out:
# <xml><var name="_dummy_ipython_val"  />
# <var name="_dummy_special_var"  />
# <var name="A2C" type="ABCMeta" qualifier="abc" value="%3Cclass %27stable_baselines3.a2c.a2c.A2C%27&gt;"
# isContainer="True" />
# <var name="env" type="OrderEnforcing" qualifier="gymnasium.wrappers.order_enforcing"
# value="%3COrderEnforcing%3CPassiveEnvChecker%3CViZDoomEnv%3CViZDoomBasic-v0&gt;&gt;&gt;&gt;" isContainer="True" />
# <var name="i" type="int" qualifier="builtins" value="0" />
# <var name="model" type="A2C" qualifier="stable_baselines3.a2c.a2c" value="%3Cstable_baselines3.a2c.a2c.A2C object
# at 0x7fbea49f4bb0&gt;" isContainer="True" />
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>
# </xml>Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------------------------------------------------
# LiveError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       3 env = gym.make('ViZDoomBasic-v0', render_mode='rgb_array')
#       5 model = A2C('MultiInputPolicy', env, verbose=1)
# ----> 6 model.learn(total_timesteps=1_000, progress_bar=True)
#       8 model.save('a2c_doom_agent')
#      10 # mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/a2c/a2c.py:194, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     185 def learn(
#     186     self: SelfA2C,
#     187     total_timesteps: int,
#    (...)
#     192     progress_bar: bool = False,
#     193 ) -> SelfA2C:
# --> 194     return super().learn(
#     195         total_timesteps=total_timesteps,
#     196         callback=callback,
#     197         log_interval=log_interval,
#     198         tb_log_name=tb_log_name,
#     199         reset_num_timesteps=reset_num_timesteps,
#     200         progress_bar=progress_bar,
#     201     )
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:254, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 iteration = 0
#     246 total_timesteps, callback = self._setup_learn(
#     247     total_timesteps,
#     248     callback,
#    (...)
#     251     progress_bar,
#     252 )
# --> 254 callback.on_training_start(locals(), globals())
#     256 assert self.env is not None
#     258 while self.num_timesteps < total_timesteps:
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:74, in BaseCallback.on_training_start(self, locals_, globals_)
#      72 # Update num_timesteps in case training was done before
#      73 self.num_timesteps = self.model.num_timesteps
# ---> 74 self._on_training_start()
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:198, in CallbackList._on_training_start(self)
#     196 def _on_training_start(self) -> None:
#     197     for callback in self.callbacks:
# --> 198         callback.on_training_start(self.locals, self.globals)
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:74, in BaseCallback.on_training_start(self, locals_, globals_)
#      72 # Update num_timesteps in case training was done before
#      73 self.num_timesteps = self.model.num_timesteps
# ---> 74 self._on_training_start()
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/stable_baselines3/common/callbacks.py:682, in ProgressBarCallback._on_training_start(self)
#     679 def _on_training_start(self) -> None:
#     680     # Initialize progress bar
#     681     # Remove timesteps that were done in previous training sessions
# --> 682     self.pbar = tqdm(total=self.locals["total_timesteps"] - self.model.num_timesteps)
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/tqdm/rich.py:113, in tqdm_rich.__init__(self, *args, **kwargs)
#     111 options.setdefault('transient', not self.leave)
#     112 self._prog = Progress(*progress, **options)
# --> 113 self._prog.__enter__()
#     114 self._task_id = self._prog.add_task(self.desc or "", **d)
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/rich/progress.py:1169, in Progress.__enter__(self)
#    1168 def __enter__(self) -> "Progress":
# -> 1169     self.start()
#    1170     return self
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/rich/progress.py:1160, in Progress.start(self)
#    1158 """Start the progress display."""
#    1159 if not self.disable:
# -> 1160     self.live.start(refresh=True)
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/rich/live.py:113, in Live.start(self, refresh)
#     111 if self._started:
#     112     return
# --> 113 self.console.set_live(self)
#     114 self._started = True
#     115 if self._screen:
#
# File ~/anaconda3/envs/DOOM/lib/python3.10/site-packages/rich/console.py:835, in Console.set_live(self, live)
#     833 with self._lock:
#     834     if self._live is not None:
# --> 835         raise errors.LiveError("Only one live display may be active at once")
#     836     self._live = live
#
# LiveError: Only one live display may be active at once
